# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
countries = os.listdir('data')

# %%
seasons = ['2021_2022.csv', '2022_2023.csv', '2023_2024.csv']

# %%
considered_features = [
    'Div'
    , 'Date'
    , 'Time'
    , 'HomeTeam'
    , 'AwayTeam'
    , 'FTHG'
    , 'FTAG'
    , 'FTR'
    , 'HTHG'
    , 'HTAG'
    , 'HTR'
    , 'HS'
    , 'AS'
    , 'HST'
    , 'AST'
    , 'HF'
    , 'AF'
    , 'HC'
    , 'AC'
    , 'HY'
    , 'AY'
    , 'HR'
    , 'AR']

# %%
def same_league_concat(country):
    concatenated = pd.DataFrame()
    for file in seasons:
        season = pd.read_csv(f'data/{country}/{file}')
        season = season[considered_features]
        concatenated = pd.concat([concatenated,season])
    return  concatenated
def global_dataset(countries):
    gloabal = pd.DataFrame()
    for country in countries:
        concat = same_league_concat(country)
        gloabal = pd.concat([gloabal,concat])
    return gloabal

# %% [markdown]
# ### global_concatenated is a dataset containing 9019 matches from 10 different leagues from 2021/2022 season until current day.

# %%
global_csv = global_dataset(countries)
global_csv.to_csv('global_concatenated.csv')

# %%
global_csv.shape
# Out:
# (9019, 23)

# %%
global_csv['Div'].value_counts()
# Out:
# I2     1060
# F2     1049
# I1     1049
# T1     1021
# F1      994
# B1      852
# N1      846
# P1      845
# G1      668
# SC0     635
# Name: Div, dtype: int64

# %%
country_csv = {}
for country in countries:
    concatenated = same_league_concat(country)
    concatenated.to_csv(f'data/{country}/concatenated.csv')
    country_csv[country] = concatenated

# %% [markdown]
# #### We have some missing rows

# %%
plt.figure(figsize=(12,8))
sns.heatmap(global_csv.isna(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 35 invalid rows : 5 from the belgium league , 29 from the turkish league , 1 from france league 2
# #### The missing values in the turkish league are coming from only 2 teams Hatayspor and Gaziantep

# %%
missing_rows = global_csv[global_csv.isna().any(axis=1)]
missing_rows
# Out:
#     Div        Date   Time             HomeTeam        AwayTeam  FTHG  FTAG  \
# 8    B1  27/07/2021  17:30         Beerschot VA   Cercle Brugge     0     1
# 188  B1  15/01/2022  15:15  Oud-Heverlee Leuven        Mechelen     5     0
# 304  B1  10/04/2022  17:30         St. Gilloise    Beerschot VA     5     0
# 124  B1  23/10/2022  17:30             Standard      Anderlecht     5     0
# 148  B1  12/11/2022  19:45            Charleroi        Mechelen     0     5
# 344  F2  22/04/2022  20:00                Nancy  Quevilly Rouen     0     3
# 203  T1  25/02/2023  13:00         Umraniyespor       Gaziantep     3     0
# 212  T1  05/03/2023  13:00        Ad. Demirspor       Hatayspor     3     0
# 213  T1  05/03/2023  13:00            Gaziantep     Galatasaray     0     3
# 221  T1  12/03/2023  10:30            Hatayspor       Konyaspor     0     3
# 232  T1  19/03/2023  18:00            Gaziantep     Trabzonspor     0     3
# 233  T1  19/03/2023  18:00          Kayserispor       Hatayspor     3     0
# 239  T1  02/04/2023  18:00            Gaziantep       Kasimpasa     0     3
# 240  T1  02/04/2023  18:00            Hatayspor       Sivasspor     0     3
# 247  T1  09/04/2023  18:00        Ad. Demirspor       Gaziantep     3     0
# 248  T1  09/04/2023  18:00           Alanyaspor       Hatayspor     3     0
# 258  T1  16/04/2023  18:00            Gaziantep       Konyaspor     0     3
# 259  T1  16/04/2023  18:00            Hatayspor      Karagumruk     0     3
# 265  T1  19/04/2023  18:00             Besiktas       Hatayspor     3     0
# 274  T1  23/04/2023  18:00            Gaziantep      Alanyaspor     0     3
# 275  T1  23/04/2023  18:00            Hatayspor      Ankaragucu     0     3
# 285  T1  30/04/2023  18:00           Buyuksehyr       Hatayspor     3     0
# 286  T1  30/04/2023  18:00          Kayserispor       Gaziantep     3     0
# 293  T1  07/05/2023  18:00            Gaziantep      Karagumruk     0     3
# 294  T1  07/05/2023  18:00            Hatayspor    Istanbulspor     0     3
# 302  T1  17/05/2023  18:00             Besiktas       Gaziantep     3     0
# 303  T1  17/05/2023  18:00          Giresunspor       Hatayspor     3     0
# 312  T1  21/05/2023  18:00            Gaziantep     Giresunspor     0     3
# 313  T1  21/05/2023  18:00            Hatayspor      Fenerbahce     0     3
# 317  T1  30/05/2023  18:00           Buyuksehyr       Gaziantep     3     0
# 320  T1  30/05/2023  18:00            Hatayspor    Umraniyespor     0     3
# 326  T1  03/06/2023  17:00          Antalyaspor       Hatayspor     3     0
# 327  T1  03/06/2023  17:00            Gaziantep    Istanbulspor     0     3
# 338  T1  07/06/2023  18:00           Fenerbahce       Gaziantep     3     0
# 340  T1  07/06/2023  18:00            Hatayspor     Galatasaray     0     3
#
#     FTR  HTHG  HTAG  ... HST  AST  HF  AF  HC  AC   HY   AY   HR   AR
# 8     A   0.0   1.0  ... NaN  NaN NaN NaN NaN NaN  1.0  1.0  0.0  0.0
# 188   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 304   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 124   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 148   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 344   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 203   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 212   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 213   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 221   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 232   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 233   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 239   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 240   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 247   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 248   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 258   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 259   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 265   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 274   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 275   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 285   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 286   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 293   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 294   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 302   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 303   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 312   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 313   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 317   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 320   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 326   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 327   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 338   H   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
# 340   A   NaN   NaN  ... NaN  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN
#
# [35 rows x 23 columns]
